# %%
from tensorflow.keras.preprocessing.text import one_hot

# %%
sent=['the cat sat on the mat',
      'the dog sat on the log',
      'the glass is on the table',
      'these are the three sentences']

# %%
#Define the vocabulary size
voc_size=1000

# %%
#one hot representation
onehot_repr=[one_hot(words,voc_size) for words in sent]
print(onehot_repr)
# Out:
# [[271, 266, 49, 707, 271, 946], [271, 219, 49, 707, 271, 775], [271, 98, 980, 707, 271, 86], [316, 803, 271, 277, 476]]

# %%
#word embedding representation

from tensorflow.keras.layers import Embedding
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential

# %%
import numpy as np

# %%
sent_length=6
embedded_docs=pad_sequences(onehot_repr,padding='pre',maxlen=sent_length)
print(embedded_docs)
# Out:
# [[271 266  49 707 271 946]
#  [271 219  49 707 271 775]
#  [271  98 980 707 271  86]
#  [  0 316 803 271 277 476]]

# %%
#feature representation using embedding
dim=10

# %%
model=Sequential()
model.add(Embedding(voc_size,dim,input_length=sent_length))
model.compile('adam','mse')

# %%
model.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_4 (Embedding)         │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.predict(embedded_docs)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# array([[[-0.04247639,  0.00342288, -0.03170754,  0.010906  ,
#           0.0028713 ,  0.01154473,  0.04443317, -0.00832504,
#           0.01247207,  0.00485741],
#         [-0.02468042,  0.02433089, -0.00729307, -0.01095178,
#          -0.02122358, -0.00474353, -0.03443457,  0.00765202,
#           0.00641458,  0.01702381],
#         [-0.04767749, -0.02910818, -0.03688664, -0.04051676,
#           0.0475605 , -0.00039821, -0.04819259, -0.04246793,
#          -0.01267665,  0.02514908],
#         [-0.02704698,  0.00856958,  0.00308015, -0.03981719,
#           0.04569629,  0.0036839 , -0.00139326,  0.02646091,
#          -0.03605112, -0.00052435],
#         [-0.04247639,  0.00342288, -0.03170754,  0.010906  ,
#           0.0028713 ,  0.01154473,  0.04443317, -0.00832504,
#           0.01247207,  0.00485741],
#         [ 0.00399976,  0.03696051, -0.012662  ,  0.01925495,
#          -0.04163538, -0.00787906,  0.04127394,  0.01275892,
#          -0.01279502,  0.03318617]],
#
#        [[-0.04247639,  0.00342288, -0.03170754,  0.010906  ,
#           0.0028713 ,  0.01154473,  0.04443317, -0.00832504,
#           0.01247207,  0.00485741],
#         [ 0.03739537,  0.02033372,  0.02468259, -0.0290399 ,
#           0.03437705,  0.03381815,  0.01009226,  0.02299012,
#          -0.00037552, -0.00945727],
#         [-0.04767749, -0.02910818, -0.03688664, -0.04051676,
#           0.0475605 , -0.00039821, -0.04819259, -0.04246793,
#          -0.01267665,  0.02514908],
#         [-0.02704698,  0.00856958,  0.00308015, -0.03981719,
#           0.04569629,  0.0036839 , -0.00139326,  0.02646091,
#          -0.03605112, -0.00052435],
#         [-0.04247639,  0.00342288, -0.03170754,  0.010906  ,
#           0.0028713 ,  0.01154473,  0.04443317, -0.00832504,
#           0.01247207,  0.00485741],
#         [ 0.03788307,  0.04776359, -0.02875271,  0.03752002,
#           0.00144758,  0.02639755,  0.02890303, -0.034252  ,
#           0.02561263, -0.02920314]],
#
#        [[-0.04247639,  0.00342288, -0.03170754,  0.010906  ,
#           0.0028713 ,  0.01154473,  0.04443317, -0.00832504,
#           0.01247207,  0.00485741],
#         [ 0.04835942,  0.03677041, -0.03995175,  0.01328963,
#           0.02727235, -0.0205749 , -0.02626892,  0.02719015,
#          -0.01137525,  0.02660563],
#         [-0.03597448, -0.00462765,  0.00152931,  0.02659993,
#          -0.02606401,  0.0126362 ,  0.02385279, -0.04297444,
#           0.03574066,  0.03288095],
#         [-0.02704698,  0.00856958,  0.00308015, -0.03981719,
#           0.04569629,  0.0036839 , -0.00139326,  0.02646091,
#          -0.03605112, -0.00052435],
#         [-0.04247639,  0.00342288, -0.03170754,  0.010906  ,
#           0.0028713 ,  0.01154473,  0.04443317, -0.00832504,
#           0.01247207,  0.00485741],
#         [-0.04219477,  0.01004233,  0.0222117 , -0.04692227,
#           0.04469525, -0.0286532 , -0.01622764, -0.00741509,
#           0.02703147,  0.04355093]],
#
#        [[ 0.02845831, -0.01206215, -0.03279363,  0.00438963,
#          -0.02828118,  0.01942954, -0.04934338,  0.01294552,
#          -0.01064147,  0.01782099],
#         [ 0.04793468, -0.01549288,  0.03401053, -0.00178339,
#          -0.03132806,  0.03769392,  0.01509836, -0.02788025,
#          -0.02384731,  0.00839763],
#         [ 0.03919718, -0.00704819, -0.00965161,  0.00774791,
#          -0.04701555,  0.00367947,  0.03816931, -0.0316412 ,
#          -0.00510442, -0.03332569],
#         [-0.04247639,  0.00342288, -0.03170754,  0.010906  ,
#           0.0028713 ,  0.01154473,  0.04443317, -0.00832504,
#           0.01247207,  0.00485741],
#         [-0.01656353,  0.01724677,  0.01780364,  0.02677046,
#          -0.04083003, -0.02411949,  0.04575279,  0.03386119,
#           0.01341685,  0.01281742],
#         [-0.04505756, -0.00951551,  0.00566279,  0.04864491,
#          -0.03643967, -0.01280934, -0.03302555, -0.04636044,
#          -0.02978891, -0.00623627]]], dtype=float32)

# %%
model.predict(embedded_docs[0].reshape(1,6))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# array([[[-0.04247639,  0.00342288, -0.03170754,  0.010906  ,
#           0.0028713 ,  0.01154473,  0.04443317, -0.00832504,
#           0.01247207,  0.00485741],
#         [-0.02468042,  0.02433089, -0.00729307, -0.01095178,
#          -0.02122358, -0.00474353, -0.03443457,  0.00765202,
#           0.00641458,  0.01702381],
#         [-0.04767749, -0.02910818, -0.03688664, -0.04051676,
#           0.0475605 , -0.00039821, -0.04819259, -0.04246793,
#          -0.01267665,  0.02514908],
#         [-0.02704698,  0.00856958,  0.00308015, -0.03981719,
#           0.04569629,  0.0036839 , -0.00139326,  0.02646091,
#          -0.03605112, -0.00052435],
#         [-0.04247639,  0.00342288, -0.03170754,  0.010906  ,
#           0.0028713 ,  0.01154473,  0.04443317, -0.00832504,
#           0.01247207,  0.00485741],
#         [ 0.00399976,  0.03696051, -0.012662  ,  0.01925495,
#          -0.04163538, -0.00787906,  0.04127394,  0.01275892,
#          -0.01279502,  0.03318617]]], dtype=float32)
